# %%
from sklearn import datasets
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
np.random.seed(0)
feature_set_x, labels_y = datasets.make_moons(1000, noise=0.10)
X_train, X_test, y_train, y_test = train_test_split(feature_set_x, labels_y, test_size=0.40, random_state=42)

# num_samples_total = 1000
# training_split = 250

# feature_set_x, labels_y  = datasets.make_moons(n_samples = num_samples_total)
# labels_y[np.where(labels_y == 0)] = -1
# X_train = feature_set_x[training_split:, :]
# X_test = feature_set_x[:training_split, :]
# y_train = labels_y[training_split:]
# y_test = labels_y[:training_split]

df = pd.DataFrame(feature_set_x)
sns.pairplot(df)

# %%
df = pd.DataFrame(dict(x= feature_set_x[:,0], y= feature_set_x[:,1], label =labels_y ))
colors = {0: "red", 1:"blue"}
fig, ax = plt.subplots()
grouped = df.groupby('label')
for key, group in grouped:
   
    group.plot(ax = ax, kind= "scatter", x="x", y="y", label= key, color = colors[key])
plt.show()

# %%
#%conda install keras

from keras.models import Sequential
from keras.utils.vis_utils import plot_model
from keras.layers import Dense, Activation, Reshape

model = Sequential()
model.add(Dense(10, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics= ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model.fit(X_train, y_train , epochs=100, batch_size= 30)
# Out:
# Epoch 1/100
# 2024-04-23 10:08:43.160845: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 20/20 [==============================] - 1s 6ms/step - loss: 0.7529 - accuracy: 0.4783
# Epoch 2/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7036 - accuracy: 0.4650
# Epoch 3/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6647 - accuracy: 0.5150
# Epoch 4/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6324 - accuracy: 0.6433
# Epoch 5/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6039 - accuracy: 0.7050
# Epoch 6/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5754 - accuracy: 0.7317
# Epoch 7/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5459 - accuracy: 0.7517
# Epoch 8/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5152 - accuracy: 0.7883
# Epoch 9/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4834 - accuracy: 0.8183
# Epoch 10/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4520 - accuracy: 0.8450
# Epoch 11/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4221 - accuracy: 0.8650
# Epoch 12/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3939 - accuracy: 0.8800
# Epoch 13/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3686 - accuracy: 0.8817
# Epoch 14/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3458 - accuracy: 0.8883
# Epoch 15/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3261 - accuracy: 0.8883
# Epoch 16/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3093 - accuracy: 0.8900
# Epoch 17/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2947 - accuracy: 0.8917
# Epoch 18/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2833 - accuracy: 0.8933
# Epoch 19/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2732 - accuracy: 0.8967
# Epoch 20/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2651 - accuracy: 0.8983
# Epoch 21/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2587 - accuracy: 0.8983
# Epoch 22/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2527 - accuracy: 0.8967
# Epoch 23/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2477 - accuracy: 0.8967
# Epoch 24/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2437 - accuracy: 0.8983
# Epoch 25/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2401 - accuracy: 0.9000
# Epoch 26/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2371 - accuracy: 0.9017
# Epoch 27/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2348 - accuracy: 0.9033
# Epoch 28/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2319 - accuracy: 0.9000
# Epoch 29/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2296 - accuracy: 0.9033
# Epoch 30/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2274 - accuracy: 0.9017
# Epoch 31/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2252 - accuracy: 0.9017
# Epoch 32/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2227 - accuracy: 0.9033
# Epoch 33/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2191 - accuracy: 0.9050
# Epoch 34/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9050
# Epoch 35/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2074 - accuracy: 0.9050
# Epoch 36/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2001 - accuracy: 0.9083
# Epoch 37/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1927 - accuracy: 0.9083
# Epoch 38/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1852 - accuracy: 0.9150
# Epoch 39/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1779 - accuracy: 0.9167
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1707 - accuracy: 0.9200
# Epoch 41/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1644 - accuracy: 0.9217
# Epoch 42/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1570 - accuracy: 0.9300
# Epoch 43/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1505 - accuracy: 0.9450
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9467
# Epoch 45/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1386 - accuracy: 0.9517
# Epoch 46/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1335 - accuracy: 0.9550
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9550
# Epoch 48/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1242 - accuracy: 0.9550
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1204 - accuracy: 0.9600
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1167 - accuracy: 0.9667
# Epoch 51/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1128 - accuracy: 0.9683
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1095 - accuracy: 0.9683
# Epoch 53/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1063 - accuracy: 0.9683
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1033 - accuracy: 0.9717
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9683
# Epoch 56/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0979 - accuracy: 0.9733
# Epoch 57/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0956 - accuracy: 0.9750
# Epoch 58/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0930 - accuracy: 0.9733
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0908 - accuracy: 0.9783
# Epoch 60/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0888 - accuracy: 0.9783
# Epoch 61/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0866 - accuracy: 0.9800
# Epoch 62/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0846 - accuracy: 0.9800
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9800
# Epoch 64/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0809 - accuracy: 0.9817
# Epoch 65/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0789 - accuracy: 0.9800
# Epoch 66/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0772 - accuracy: 0.9817
# Epoch 67/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9817
# Epoch 68/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0741 - accuracy: 0.9833
# Epoch 69/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0724 - accuracy: 0.9817
# Epoch 70/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0707 - accuracy: 0.9833
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0693 - accuracy: 0.9833
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0677 - accuracy: 0.9833
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0664 - accuracy: 0.9833
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0650 - accuracy: 0.9833
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0637 - accuracy: 0.9833
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 0.9833
# Epoch 77/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0608 - accuracy: 0.9867
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0599 - accuracy: 0.9833
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0589 - accuracy: 0.9867
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0571 - accuracy: 0.9867
# Epoch 81/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 0.9867
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0547 - accuracy: 0.9867
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9867
# Epoch 84/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0524 - accuracy: 0.9867
# Epoch 85/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9867
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9867
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9867
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 0.9867
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9867
# Epoch 90/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0460 - accuracy: 0.9883
# Epoch 91/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0452 - accuracy: 0.9883
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0442 - accuracy: 0.9883
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9900
# Epoch 94/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0426 - accuracy: 0.9900
# Epoch 95/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0415 - accuracy: 0.9900
# Epoch 96/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0407 - accuracy: 0.9900
# Epoch 97/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 0.9900
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 0.9900
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 0.9900
# Epoch 100/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0372 - accuracy: 0.9900

# %%
sns.lineplot(x=results.epoch, y=results.history['loss'])
# Out:
# <Axes: >

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.058958400040864944
# Test accuracy: 0.9775000214576721

# %%
from sklearn import metrics
from mlxtend.plotting import plot_decision_regions


prediction_values = (model.predict(X_test) > 0.5).astype(int)
# Out:
# 13/13 [==============================] - 0s 3ms/step

# %%
print(metrics.classification_report(y_test, prediction_values))
plot_decision_regions(X_train, y_train, clf=model, legend=2)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       187
#            1       0.97      0.99      0.98       213
#
#     accuracy                           0.98       400
#    macro avg       0.98      0.98      0.98       400
# weighted avg       0.98      0.98      0.98       400
#
# 9600/9600 [==============================] - 16s 2ms/step

# %%
# from ann_visualizer.visualize import ann_viz
# ann_viz(model, title="Hafl moon neural network")
